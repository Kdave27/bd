# %%
import numpy as np
import pandas as pd
import string

def read_file(file_path):
    with open(file_path,'r') as file:
        text=file.read()
    return text

def remove_punctuation(text):
    translator=str.maketrans('','',string.punctuation)
    cleaned_text=text.translate(translator)
    words=cleaned_text.split()
    return words

def k_shingles(words,k):
    k_shingles=[]
    for i in range(len(words)-k+1):
        k_shingles.append(''.join(words[i:i+k]))
    return k_shingles
k=5

file_path1='Desktop/worldwar1.txt'
text1=read_file(file_path1)
words1=remove_punctuation(text1)
shingles1=k_shingles(words1,k)

file_path2='Desktop/worldwar2.txt'
text2=read_file(file_path2)
words2=remove_punctuation(text2)
shingles2=k_shingles(words2,k)

file_path3='Desktop/worldwar3.txt'
text3=read_file(file_path3)
words3=remove_punctuation(text3)
shingles3=k_shingles(words3,k)

# %%
allshingles=shingles1+shingles2+shingles3

unique_shingles=list(set(allshingles))
print(len(unique_shingles))
# Out:
# 1650

# %%
incidence_matrix=np.zeros((len(unique_shingles),3))

for shingles in enumerate(unique_shingles):
    if shingles in shingles1:
        incidence_matrix[i,0]=1
    if shingles in shingles2:
        incidence_matrix[i,1]=1
    if shingles in shingles3:
        incidence_matrix[i,2]=1  

incidence_df=pd.DataFrame(incidence_matrix,index=unique_shingles,columns=['Document1','Document2','Document3'])
incidence_df.insert(0,"row",range(0,len(unique_shingles)))
print(incidence_df)
# Out:
#                                             row  Document1  Document2  \
# FrancetheSovietUnionthe                       0        0.0        0.0
# andaircraftplayedmajorroles                   1        0.0        0.0
# bombsonHiroshimaon6                           2        0.0        0.0
# WarInthewakeof                                3        0.0        0.0
# upto8millioncivilian                          4        0.0        0.0
# ...                                         ...        ...        ...
# Germanysresumptionofunrestrictedsubmarine  1645        0.0        0.0
# RussianinvasionofUkrainesince              1646        0.0        0.0
# USâ€”becomingthepermanentmembersof         1647        0.0        0.0
# Statesintheatomicbombings                  1648        0.0        0.0
# wellaspartsofAfrica                        1649        0.0        0.0
#
#                                            Document3
# FrancetheSovietUnionthe                          0.0
# andaircraftplayedmajorroles                      0.0
# bombsonHiroshimaon6                              0.0
# WarInthewakeof                                   0.0
# upto8millioncivilian                             0.0
# ...                                              ...
# Germanysresumptionofunrestrictedsubmarine        0.0
# RussianinvasionofUkrainesince                    0.0
# USâ€”becomingthepermanentmembersof               0.0
# Statesintheatomicbombings                        0.0
# wellaspartsofAfrica                              0.0
#
# [1650 rows x 4 columns]

# %%
incidence_df['h1']=(incidence_df['row']+1)%1000
incidence_df['h2']=(2*incidence_df['row']+5)%1000

incidence_df=incidence_df.sort_values(by=['h1','h2'])
print(incidence_df)
# Out:
#                                       row  Document1  Document2  Document3  \
# withtheliberationofGermanoccupied     999        0.0        0.0        0.0
# FrancetheSovietUnionthe                 0        0.0        0.0        0.0
# aboutWorldWarIIIWith                 1000        0.0        0.0        0.0
# andaircraftplayedmajorroles             1        0.0        0.0        0.0
# HitlerinvadedPolandTheUnited         1001        0.0        0.0        0.0
# ...                                   ...        ...        ...        ...
# Ukrainesince2022aswell                994        0.0        0.0        0.0
# millionwoundedplusupto                995        0.0        0.0        0.0
# andtheBlitzofthe                      996        0.0        0.0        0.0
# AlliesinvadedGermanoccupiedFranceat   997        0.0        0.0        0.0
# andtheMiddleEastas                    998        0.0        0.0        0.0
#
#                                       h1   h2
# withtheliberationofGermanoccupied      0    3
# FrancetheSovietUnionthe                1    5
# aboutWorldWarIIIWith                   1    5
# andaircraftplayedmajorroles            2    7
# HitlerinvadedPolandTheUnited           2    7
# ...                                  ...  ...
# Ukrainesince2022aswell               995  993
# millionwoundedplusupto               996  995
# andtheBlitzofthe                     997  997
# AlliesinvadedGermanoccupiedFranceat  998  999
# andtheMiddleEastas                   999    1
#
# [1650 rows x 6 columns]

# %%
num_hashes=2
num_docs=3
signature_matrix=np.full((num_hashes,num_docs),np.inf)
print(signature_matrix)
for i in range(len(unique_shingles)):
    if incidence_df.iloc[i, 1] == 1:  # Document 1
        signature_matrix[0, 0] = min(signature_matrix[0, 0], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 0] = min(signature_matrix[1, 0], incidence_df.iloc[i]['h2'])
    if incidence_df.iloc[i, 2] == 1:  # Document 2
        signature_matrix[0, 1] = min(signature_matrix[0, 1], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 1] = min(signature_matrix[1, 1], incidence_df.iloc[i]['h2'])
    if incidence_df.iloc[i, 3] == 1:  # Document 3
        signature_matrix[0, 2] = min(signature_matrix[0, 2], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 2] = min(signature_matrix[1, 2], incidence_df.iloc[i]['h2'])
print(signature_matrix)

signature_df = pd.DataFrame(signature_matrix, index=['h1', 'h2'], columns=["Document 1", "Document 2", "Document 3"])
print("\nsignature_matrix :\n")
print(signature_df)
# Out:
# [[inf inf inf]
#  [inf inf inf]]
# [[inf inf inf]
#  [inf inf inf]]
#
# signature_matrix :
#
#     Document 1  Document 2  Document 3
# h1         inf         inf         inf
# h2         inf         inf         inf

# %%
import string
import numpy as np
import pandas as pd
def read_file(file_path):
    with open(file_path,'r') as file:
        text=file.read()
    return text
#f=open("Desktop/worldwar1.txt","r")
#text=f.read()

def remove_punctuation(text):
    translator=str.maketrans('','',string.punctuation)
    cleaned_text=text.translate(translator)
    words=cleaned_text.split()
    return words
#print(cleaned_text)


#for word in words:
    #print(word)
def generate_k_shingles(words,k):
    k_shingles=[''.join(words[i:i+k]) for i in range(len(words)-k+1)]
    return k_shingles

k=5
file_path1='Desktop/worldwar1.txt'
text1=read_file(file_path1)
words1=remove_punctuation(text1)
shingles1=generate_k_shingles(words1,k)
#for shingle in shingles1:
 #   print(shingle)

file_path2='Desktop/worldwar2.txt'
text2=read_file(file_path2)
words2=remove_punctuation(text2)
shingles2=generate_k_shingles(words2,k)
#for shingle in shingles2:
    #print(shingle)

file_path3='Desktop/worldwar3.txt'
text3=read_file(file_path3)
words3=remove_punctuation(text3)
shingles3=generate_k_shingles(words3,k)
#for shingle in shingles3:
    #print(shingle)

all_shingles=shingles1+shingles2+shingles3
#print(all_shingles)






#unique_shingles=list(set(all_shingles))
#print(unique_shingles)
#incidence_matrix=np.zeros((len(unique_shingles),len(a1)),dtype=int)



#for i, unique_shingle in enumerate(unique_shingles):
 #   for j, shingle in enumerate(a1):
  #      if unique_shingle==a1:
   #         incidence_matrix[i][j]=1

#print(incidence_matrix)


# Step 1: Combine all shingles and find unique shingles
unique_shingles = list(set(all_shingles))
print(len(unique_shingles))
# Step 2: Initialize an empty incidence matrix
incidence_matrix = np.zeros((len(unique_shingles), 3))  # 3 documents in this case

# Step 3: Populate the incidence matrix
for i, shingle in enumerate(unique_shingles):
    if shingle in shingles1:
        incidence_matrix[i, 0] = 1  # Document 1
    if shingle in shingles2:
        incidence_matrix[i, 1] = 1  # Document 2
    if shingle in shingles3:
        incidence_matrix[i, 2] = 1  # Document 3

# Step 4: Create a DataFrame for better visualization (optional)
incidence_df = pd.DataFrame(incidence_matrix, index=unique_shingles, columns=["Document 1", "Document 2", "Document 3"])
incidence_df.insert(0,"Row",range(0,len(unique_shingles)))
# Print the incidence matrix
print(incidence_df)
#apply Hash Function
incidence_df['h1'] = (incidence_df['Row']+1) % 1000
incidence_df['h2'] = (2 * incidence_df['Row']+5) % 1000

incidence_df = incidence_df.sort_values(by=['h1','h2'])

print(incidence_df)
num_hashes = 2
num_docs = 3
signature_matrix = np.full((num_hashes, num_docs), np.inf)  # (2 x 3) matrix
print(signature_matrix)

for i in range(len(unique_shingles)):
    if incidence_df.iloc[i, 1] == 1:  # Document 1
        signature_matrix[0, 0] = min(signature_matrix[0, 0], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 0] = min(signature_matrix[1, 0], incidence_df.iloc[i]['h2'])
    if incidence_df.iloc[i, 2] == 1:  # Document 2
        signature_matrix[0, 1] = min(signature_matrix[0, 1], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 1] = min(signature_matrix[1, 1], incidence_df.iloc[i]['h2'])
    if incidence_df.iloc[i, 3] == 1:  # Document 3
        signature_matrix[0, 2] = min(signature_matrix[0, 2], incidence_df.iloc[i]['h1'])
        signature_matrix[1, 2] = min(signature_matrix[1, 2], incidence_df.iloc[i]['h2'])
print(signature_matrix)

signature_df = pd.DataFrame(signature_matrix, index=['h1', 'h2'], columns=["Document 1", "Document 2", "Document 3"])
print("\nsignature_matrix :\n")
print(signature_df)
# Out:
# 1650
#                                             Row  Document 1  Document 2  \
# FrancetheSovietUnionthe                       0         0.0         1.0
# andaircraftplayedmajorroles                   1         0.0         1.0
# bombsonHiroshimaon6                           2         0.0         1.0
# WarInthewakeof                                3         0.0         1.0
# upto8millioncivilian                          4         1.0         0.0
# ...                                         ...         ...         ...
# Germanysresumptionofunrestrictedsubmarine  1645         1.0         0.0
# RussianinvasionofUkrainesince              1646         0.0         0.0
# USâ€”becomingthepermanentmembersof         1647         0.0         1.0
# Statesintheatomicbombings                  1648         0.0         0.0
# wellaspartsofAfrica                        1649         1.0         0.0
#
#                                            Document 3
# FrancetheSovietUnionthe                           0.0
# andaircraftplayedmajorroles                       0.0
# bombsonHiroshimaon6                               0.0
# WarInthewakeof                                    0.0
# upto8millioncivilian                              0.0
# ...                                               ...
# Germanysresumptionofunrestrictedsubmarine         0.0
# RussianinvasionofUkrainesince                     1.0
# USâ€”becomingthepermanentmembersof                0.0
# Statesintheatomicbombings                         1.0
# wellaspartsofAfrica                               0.0
#
# [1650 rows x 4 columns]
#                                       Row  Document 1  Document 2  Document 3  \
# withtheliberationofGermanoccupied     999         0.0         1.0         0.0
# FrancetheSovietUnionthe                 0         0.0         1.0         0.0
# aboutWorldWarIIIWith                 1000         0.0         0.0         1.0
# andaircraftplayedmajorroles             1         0.0         1.0         0.0
# HitlerinvadedPolandTheUnited         1001         0.0         1.0         0.0
# ...                                   ...         ...         ...         ...
# Ukrainesince2022aswell                994         0.0         0.0         1.0
# millionwoundedplusupto                995         1.0         0.0         0.0
# andtheBlitzofthe                      996         0.0         1.0         0.0
# AlliesinvadedGermanoccupiedFranceat   997         0.0         1.0         0.0
# andtheMiddleEastas                    998         1.0         0.0         0.0
#
#                                       h1   h2
# withtheliberationofGermanoccupied      0    3
# FrancetheSovietUnionthe                1    5
# aboutWorldWarIIIWith                   1    5
# andaircraftplayedmajorroles            2    7
# HitlerinvadedPolandTheUnited           2    7
# ...                                  ...  ...
# Ukrainesince2022aswell               995  993
# millionwoundedplusupto               996  995
# andtheBlitzofthe                     997  997
# AlliesinvadedGermanoccupiedFranceat  998  999
# andtheMiddleEastas                   999    1
#
# [1650 rows x 6 columns]
# [[inf inf inf]
#  [inf inf inf]]
# [[4. 0. 1.]
#  [1. 1. 3.]]
#
# signature_matrix :
#
#     Document 1  Document 2  Document 3
# h1         4.0         0.0         1.0
# h2         1.0         1.0         3.0
